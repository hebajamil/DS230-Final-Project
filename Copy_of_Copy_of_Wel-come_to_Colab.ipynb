# %% [markdown]
# <a href="https://colab.research.google.com/github/hebajamil/DS230-Final-Project/blob/main/Copy_of_Copy_of_Wel-come_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Malak")
# Out:
# Malak
